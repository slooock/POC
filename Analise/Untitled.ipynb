# %%
import pandas as pd

# %%
base = pd.read_csv('dados.csv')

# %%
base
# Out:
#          idcidade  idindicador   ano     valor  idhistorico  idcidade.1  \
# 0         1100015         5908  2005      5684            1     1100015
# 1         1100015         5908  2007      5325            2     1100015
# 2         1100015         5908  2009      4977            3     1100015
# 3         1100015         5908  2010      4734            4     1100015
# 4         1100015         5908  2011      4473            5     1100015
# 5         1100015         5908  2012      4212            6     1100015
# 6         1100015         5908  2013      4062            7     1100015
# 7         1100015         5908  2014      4145            8     1100015
# 8         1100015         5908  2015      3944            9     1100015
# 9         1100015         5908  2016      4108           10     1100015
# 10        1100015         5908  2017      3964           11     1100015
# 11        1100015         5908  2018      3918           12     1100015
# ...
