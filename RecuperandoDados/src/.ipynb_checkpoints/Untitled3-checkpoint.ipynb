# %%
import json
import requests
import pymysql.cursors
from datetime import datetime
import sys
import time
import numpy as np
import pandas as pd
from fake_useragent import UserAgent
import time 
ua = UserAgent()

# %%
def conectaBanco():
	con = pymysql.connect(host = '127.0.0.1',
                      	      user = 'root',
                              passwd='root',
                              db = 'Prefeitura',
							  use_unicode=True,
							  charset="utf8",
                              cursorclass=pymysql.cursors.DictCursor)
	return con

# %%
def limpaDadosBanco(nomeTabela):
	con = conectaBanco()
	cursor = con.cursor()

	sqlquery = "SET FOREIGN_KEY_CHECKS = 0;"
	cursor.execute(sqlquery)
	con.commit()

	sqlquery = "TRUNCATE "+nomeTabela+";"
	cursor.execute(sqlquery)
	con.commit()
	print("DADOS DA TABELA "+nomeTabela+" EXCLUIDOS")
	con.close()

# %%
def salvaCidadeJson():
    #recupera cidades da api do IBGE
    link = "https://servicodados.ibge.gov.br/api/v1/localidades/municipios"
    header = {'User-Agent':str(ua.chrome)}
    cidades = []

    marcador = True
    while(marcador):
        marcador = False
        try:
            r = requests.get(link,headers = header)
            if r.status_code == 200:

                reddit_data = json.loads(r.content)

                #Salva as cidades recuperadas em um arquivo cidades.json
                with open('cidades/cidades.json', 'w') as json_file:  
                    json.dump(reddit_data, json_file)

            else:
                print("")
                print("= HTTP Error 503. The service is unavailable. =")
        except requests.ConnectionError:
            print('Sem conexao com internet, aguardando conexao')
            marcador = True

# %%
def lerCidadesJson():
    # lemos o JSON em disco
    conteudo = open('cidades/cidades.json').read()
    cidades = []
    listajson = json.loads(conteudo)

    for cidade in listajson:
        cidades.append([cidade['id'],cidade['nome']])
    return cidades

# %%
def insereCidadesBanco(cidades):
    con = conectaBanco()
    for cidade in cidades:
        try:
            cidade[1] = cidade[1].replace("'","\\'")
            sql = "INSERT INTO cidade (idCidade,nome) values ("+str(cidade[0])+",'"+str(cidade[1])+"')"
    #         print(sql)
            cursor = con.cursor()
            cursor.execute(sql)
            con.commit()
        except pymysql.IntegrityError as e:
            print(str(e))
    con.close()

# %%
def salvaPesquisaJson():
    link = "https://servicodados.ibge.gov.br/api/v1/pesquisas/"
    header = {'User-Agent':str(ua.chrome)}

    marcador = True
    while(marcador):
        marcador = False
        try:
            r = requests.get(link,headers=header)
            if r.status_code == 200:

                reddit_data = json.loads(r.content)

                with open('pesquisas/pesquisas.json', 'w') as json_file:  
                    json.dump(reddit_data, json_file)

            else:
                print(idPesquisa)
                print("= HTTP Error 503. The service is unavailable. =")
        except requests.ConnectionError:
            print('Sem conexao com internet, aguardando conexao')
            marcador = True

# %%
def lerPesquisasJson():
    # lemos o JSON em disco
    conteudo = open('pesquisas/pesquisas.json').read()
    pesquisas = []
    listajson = json.loads(conteudo)

    for pesquisa in listajson:
        pesquisas.append([pesquisa['id'],pesquisa['nome']])
    return pesquisas

# %%
def inserePesquisasBanco(pesquisas):
    con = conectaBanco()
    for pesquisa in pesquisas:
        try:
            pesquisa[1] = pesquisa[1].replace("'","\\'")
            sql = "INSERT INTO pesquisa (idpesquisa,nome) values ("+str(pesquisa[0])+",'"+str(pesquisa[1])+"')"
    #         print(sql)
            cursor = con.cursor()
            cursor.execute(sql)
            con.commit()
        except pymysql.IntegrityError as e:
            print(str(e))
    con.close()

# %%
def salvaIndicadoresJson(pesquisas):
    for pesquisa in pesquisas:
        link = "https://servicodados.ibge.gov.br/api/v1/pesquisas/"+str(pesquisa[0])+"/indicadores"
        header = {'User-Agent':str(ua.chrome)}

        marcador = True
        while(marcador):
            marcador = False
            try:
                r = requests.get(link,headers=header)
                if r.status_code == 200:

                    reddit_data = json.loads(r.content)


                    with open('pesquisas/indicadores/'+str(pesquisa[0])+'.json', 'w') as json_file:  
                        json.dump(reddit_data, json_file)

            except requests.ConnectionError:
                print('Sem conexao com internet, aguardando conexao')
                marcador = True

# %%
def lerIndicadoresFilhos(listajson,indicadores):
    for indicador in listajson:
        indicadores.append([indicador['id'],indicador['indicador']])
        if(len(indicador['children'])>0):
            lerIndicadoresFilhos(indicador['children'],indicadores)

# %%
def lerIndicadoresJson(pesquisas):
    indicadores = []
    for pesquisa in pesquisas:
        try:
            conteudo = open('pesquisas/indicadores/'+str(pesquisa[0])+'.json').read()
            listajson = json.loads(conteudo)

            lerIndicadoresFilhos(listajson,indicadores)
        except FileNotFoundError:
            print('A pesquisa '+str(pesquisa[0])+' nao possui indicadores')
    return indicadores

# %%
def insereIndicadoresBanco(indicadores):
    con = conectaBanco()
    for indicador in indicadores:
        try:
            indicador[1] = indicador[1].replace("'","\\'")
            sql = "INSERT INTO indicador (idindicador,indicador) values ("+str(indicador[0])+",'"+str(indicador[1])+"')"
    #         print(sql)
            cursor = con.cursor()
            cursor.execute(sql)
            con.commit()
        except pymysql.IntegrityError as e:
            print(str(e))
    con.close()

# %%
def retornaIndicadoresASeremPesquisados():
    return open('pesquisas/indicadores/indicadores.txt').read()

# %%
def salvaHistoricoJson(codIBGE,indicadores):
#     codIBGE = 314710
    link = "https://servicodados.ibge.gov.br/api/v1/pesquisas/indicadores/"+indicadores+"/resultados/"+str(codIBGE)

    header = {'User-Agent':str(ua.chrome)}
    contador = 0
    metricas = []

    r = requests.get(link,headers = header)
    if r.status_code == 200:
        reddit_data = json.loads(r.content)

         #Salva as cidades recuperadas em um arquivo cidades.json
        with open('historico/'+str(codIBGE)+'.json', 'w') as json_file:  
            json.dump(reddit_data, json_file)

    else:
        print(r.status_code)
        print("= HTTP Error 503. The service is unavailable. =")

# %%
def salvaHistoricoParaCidadesJson(cidades,indicadores):
    for cidade in cidades:
        marcador = True
        while(marcador):
            marcador = False
            try:
                salvaHistoricoJson(cidade[0],indicadores)
            except:
                print(cidade)
                marcador = True

# %%
def lerHistoricoJson(cidades):
    historico = []

    for cidade in cidades:
        conteudo = open('historico/'+str(cidade[0])+'.json').read()
        listajson = json.loads(conteudo)
        for pesq in listajson:    
            for item in pesq['res'][0]['res']:
                historico.append([cidade[0],pesq['id'],item,pesq['res'][0]['res'][item]])
    return historico

# %%
def insereHistoricoBanco(historico):
    con = conectaBanco()
    for pesq in historico:
        try:
            pesq[3] = pesq[3].replace("'","\\'")
            sql = "INSERT INTO historico (idcidade,idindicador,ano,valor) values ("+str(pesq[0])+","+str(pesq[1])+","+str(pesq[2])+",'"+str(pesq[3])+"')"
    #         print(sql)
            cursor = con.cursor()
            cursor.execute(sql)
            con.commit()
        except pymysql.IntegrityError as e:
            print(str(e))
    con.close()

# %% [markdown]
# ## Main

# %% [markdown]
# ## Cidades
# * Recuperando cidades salvando num json
# * Lendo json salvando cidades num vetor
# * Adicionando cidades no banco

# %%
inicioTime = time.time()

# %%
limpaDadosBanco('cidade')
limpaDadosBanco('pesquisa')
limpaDadosBanco('indicador')
limpaDadosBanco('historico')

# %%
salvaCidadeJson()
cidades = lerCidadesJson()
insereCidadesBanco(cidades)

#Contagem de tempo
cidadeTime = time.time()
# Out:
# (1062, "Duplicate entry '1100015' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100023' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100031' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100049' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100056' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100064' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100072' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100080' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100098' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100106' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100114' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100122' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100130' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100148' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100155' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100189' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100205' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100254' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100262' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100288' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100296' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100304' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100320' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100338' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100346' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100379' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100403' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100452' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100502' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100601' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100700' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100809' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100908' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100924' for key 'PRIMARY'")
# (1062, "Duplicate entry '1100940' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101005' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101104' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101203' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101401' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101435' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101450' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101468' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101476' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101484' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101492' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101500' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101559' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101609' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101708' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101757' for key 'PRIMARY'")
# (1062, "Duplicate entry '1101807' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200013' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200054' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200104' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200138' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200179' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200203' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200252' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200328' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200336' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200344' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200351' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200385' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200393' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200401' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200427' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200435' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200450' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200500' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200609' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200708' for key 'PRIMARY'")
# (1062, "Duplicate entry '1200807' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300029' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300060' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300086' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300102' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300144' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300201' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300300' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300409' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300508' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300607' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300631' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300680' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300706' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300805' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300839' for key 'PRIMARY'")
# (1062, "Duplicate entry '1300904' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301001' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301100' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301159' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301209' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301308' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301407' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301506' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301605' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301654' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301704' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301803' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301852' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301902' for key 'PRIMARY'")
# (1062, "Duplicate entry '1301951' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302009' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302108' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302207' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302306' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302405' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302504' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302553' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302603' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302702' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302801' for key 'PRIMARY'")
# (1062, "Duplicate entry '1302900' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303007' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303106' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303205' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303304' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303403' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303502' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303536' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303569' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303601' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303700' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303809' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303908' for key 'PRIMARY'")
# (1062, "Duplicate entry '1303957' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304005' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304062' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304104' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304203' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304237' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304260' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1304401' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400027' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400050' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400100' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400159' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400175' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400209' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400233' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400282' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400308' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400407' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400456' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400472' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400506' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400605' for key 'PRIMARY'")
# (1062, "Duplicate entry '1400704' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500107' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500131' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500206' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500305' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500347' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500404' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500503' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500602' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500701' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500800' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500859' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500909' for key 'PRIMARY'")
# (1062, "Duplicate entry '1500958' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501006' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501105' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501204' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501253' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501303' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501402' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501451' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501501' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501576' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501600' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501709' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501725' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501758' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501782' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501808' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501907' for key 'PRIMARY'")
# (1062, "Duplicate entry '1501956' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502004' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502103' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502152' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502202' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502301' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502400' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502509' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502608' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502707' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502756' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502764' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502772' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502806' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502855' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502905' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502939' for key 'PRIMARY'")
# (1062, "Duplicate entry '1502954' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503002' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503044' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503077' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503093' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503101' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503200' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503309' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503408' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503457' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503507' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503606' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503705' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503754' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503804' for key 'PRIMARY'")
# (1062, "Duplicate entry '1503903' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504000' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504059' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504109' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504208' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504307' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504406' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504422' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504455' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504505' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504604' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504703' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504752' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504802' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504901' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504950' for key 'PRIMARY'")
# (1062, "Duplicate entry '1504976' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505007' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505031' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505064' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505106' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505205' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505304' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505403' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505437' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505486' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505494' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505502' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505536' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505551' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505601' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505635' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505650' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505700' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505809' for key 'PRIMARY'")
# (1062, "Duplicate entry '1505908' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506005' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506104' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506112' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506138' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506161' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506187' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506195' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506203' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506351' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506401' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506500' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506559' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506583' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506609' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506708' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506807' for key 'PRIMARY'")
# (1062, "Duplicate entry '1506906' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507003' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507102' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507151' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507201' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507300' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507409' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507458' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507466' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507474' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507508' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507607' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507706' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507755' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507805' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507904' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507953' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507961' for key 'PRIMARY'")
# (1062, "Duplicate entry '1507979' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508001' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508035' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508050' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508084' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508100' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508126' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508159' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508209' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508308' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508357' for key 'PRIMARY'")
# (1062, "Duplicate entry '1508407' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600055' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600105' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600154' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600204' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600212' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600238' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600253' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600279' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600303' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600402' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600501' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600535' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600550' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600600' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600709' for key 'PRIMARY'")
# (1062, "Duplicate entry '1600808' for key 'PRIMARY'")
# (1062, "Duplicate entry '1700251' for key 'PRIMARY'")
# (1062, "Duplicate entry '1700301' for key 'PRIMARY'")
# (1062, "Duplicate entry '1700350' for key 'PRIMARY'")
# (1062, "Duplicate entry '1700400' for key 'PRIMARY'")
# (1062, "Duplicate entry '1700707' for key 'PRIMARY'")
# (1062, "Duplicate entry '1701002' for key 'PRIMARY'")
# (1062, "Duplicate entry '1701051' for key 'PRIMARY'")
# (1062, "Duplicate entry '1701101' for key 'PRIMARY'")
# (1062, "Duplicate entry '1701309' for key 'PRIMARY'")
# (1062, "Duplicate entry '1701903' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702000' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702109' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702158' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702208' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702307' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702406' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702554' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702703' for key 'PRIMARY'")
# (1062, "Duplicate entry '1702901' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703008' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703057' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703073' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703107' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703206' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703305' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703602' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703701' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703800' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703826' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703842' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703867' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703883' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703891' for key 'PRIMARY'")
# (1062, "Duplicate entry '1703909' for key 'PRIMARY'")
# (1062, "Duplicate entry '1704105' for key 'PRIMARY'")
# (1062, "Duplicate entry '1704600' for key 'PRIMARY'")
# (1062, "Duplicate entry '1705102' for key 'PRIMARY'")
# (1062, "Duplicate entry '1705508' for key 'PRIMARY'")
# (1062, "Duplicate entry '1705557' for key 'PRIMARY'")
# (1062, "Duplicate entry '1705607' for key 'PRIMARY'")
# (1062, "Duplicate entry '1706001' for key 'PRIMARY'")
# (1062, "Duplicate entry '1706100' for key 'PRIMARY'")
# (1062, "Duplicate entry '1706258' for key 'PRIMARY'")
# (1062, "Duplicate entry '1706506' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707009' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707108' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707207' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707306' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707405' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707553' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707652' for key 'PRIMARY'")
# (1062, "Duplicate entry '1707702' for key 'PRIMARY'")
# (1062, "Duplicate entry '1708205' for key 'PRIMARY'")
# (1062, "Duplicate entry '1708254' for key 'PRIMARY'")
# (1062, "Duplicate entry '1708304' for key 'PRIMARY'")
# (1062, "Duplicate entry '1709005' for key 'PRIMARY'")
# (1062, "Duplicate entry '1709302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1709500' for key 'PRIMARY'")
# (1062, "Duplicate entry '1709807' for key 'PRIMARY'")
# (1062, "Duplicate entry '1710508' for key 'PRIMARY'")
# (1062, "Duplicate entry '1710706' for key 'PRIMARY'")
# (1062, "Duplicate entry '1710904' for key 'PRIMARY'")
# (1062, "Duplicate entry '1711100' for key 'PRIMARY'")
# (1062, "Duplicate entry '1711506' for key 'PRIMARY'")
# (1062, "Duplicate entry '1711803' for key 'PRIMARY'")
# (1062, "Duplicate entry '1711902' for key 'PRIMARY'")
# (1062, "Duplicate entry '1711951' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712009' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712157' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712405' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712454' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712504' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712702' for key 'PRIMARY'")
# (1062, "Duplicate entry '1712801' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713205' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713304' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713601' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713700' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713809' for key 'PRIMARY'")
# (1062, "Duplicate entry '1713957' for key 'PRIMARY'")
# (1062, "Duplicate entry '1714203' for key 'PRIMARY'")
# (1062, "Duplicate entry '1714302' for key 'PRIMARY'")
# (1062, "Duplicate entry '1714880' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715002' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715101' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715150' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715259' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715507' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715705' for key 'PRIMARY'")
# (1062, "Duplicate entry '1715754' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716109' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716208' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716307' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716505' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716604' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716653' for key 'PRIMARY'")
# (1062, "Duplicate entry '1716703' for key 'PRIMARY'")
# (1062, "Duplicate entry '1717008' for key 'PRIMARY'")
# (1062, "Duplicate entry '1717206' for key 'PRIMARY'")
# (1062, "Duplicate entry '1717503' for key 'PRIMARY'")
# (1062, "Duplicate entry '1717800' for key 'PRIMARY'")
# (1062, "Duplicate entry '1717909' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718006' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718204' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718303' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718402' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718451' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718501' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718550' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718659' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718709' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718758' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718808' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718840' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718865' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718881' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718899' for key 'PRIMARY'")
# (1062, "Duplicate entry '1718907' for key 'PRIMARY'")
# (1062, "Duplicate entry '1719004' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720002' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720101' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720150' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720200' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720259' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720309' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720499' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720655' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720804' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720853' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720903' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720937' for key 'PRIMARY'")
# (1062, "Duplicate entry '1720978' for key 'PRIMARY'")
# (1062, "Duplicate entry '1721000' for key 'PRIMARY'")
# (1062, "Duplicate entry '1721109' for key 'PRIMARY'")
# (1062, "Duplicate entry '1721208' for key 'PRIMARY'")
# (1062, "Duplicate entry '1721257' for key 'PRIMARY'")
# (1062, "Duplicate entry '1721307' for key 'PRIMARY'")
# (1062, "Duplicate entry '1722081' for key 'PRIMARY'")
# (1062, "Duplicate entry '1722107' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100055' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100105' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100154' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100204' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100303' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100402' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100436' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100477' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100501' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100550' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100600' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100709' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100808' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100832' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100873' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100907' for key 'PRIMARY'")
# (1062, "Duplicate entry '2100956' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101004' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101103' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101202' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101251' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101301' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101350' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101400' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101509' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101608' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101707' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101731' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101772' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101806' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101905' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101939' for key 'PRIMARY'")
# (1062, "Duplicate entry '2101970' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102002' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102036' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102077' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102101' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102150' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102200' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102309' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102325' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102358' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102374' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102408' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102507' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102556' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102606' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102705' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102754' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102804' for key 'PRIMARY'")
# (1062, "Duplicate entry '2102903' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103000' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103109' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103125' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103158' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103174' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103208' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103257' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103307' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103406' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103505' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103554' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103604' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103703' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103752' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103802' for key 'PRIMARY'")
# (1062, "Duplicate entry '2103901' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104008' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104057' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104073' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104081' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104099' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104107' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104206' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104305' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104404' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104503' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104552' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104602' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104628' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104651' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104677' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104701' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104800' for key 'PRIMARY'")
# (1062, "Duplicate entry '2104909' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105005' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105104' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105153' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105203' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105302' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105351' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105401' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105427' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105450' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105476' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105500' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105609' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105658' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105708' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105807' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105906' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105922' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105948' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105963' for key 'PRIMARY'")
# (1062, "Duplicate entry '2105989' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106003' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106102' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106201' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106300' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106326' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106359' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106375' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106409' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106508' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106607' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106631' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106672' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106706' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106755' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106805' for key 'PRIMARY'")
# (1062, "Duplicate entry '2106904' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107001' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107100' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107209' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107258' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107308' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107357' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107407' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107456' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107506' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107605' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107704' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107803' for key 'PRIMARY'")
# (1062, "Duplicate entry '2107902' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108009' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108058' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108108' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108207' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108256' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108306' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108405' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108454' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108504' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108603' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108702' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108801' for key 'PRIMARY'")
# (1062, "Duplicate entry '2108900' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109007' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109056' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109106' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109205' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109239' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109270' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109304' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109403' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109452' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109502' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109551' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109601' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109700' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109759' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109809' for key 'PRIMARY'")
# (1062, "Duplicate entry '2109908' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110005' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110039' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110104' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110203' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110237' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110278' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110302' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110401' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110500' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110609' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110658' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110708' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110807' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110856' for key 'PRIMARY'")
# (1062, "Duplicate entry '2110906' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111003' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111029' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111052' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111078' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111102' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111201' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111250' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111300' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111409' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111508' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111532' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111573' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111607' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111631' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111672' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111706' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111722' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111748' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111763' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111789' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111805' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111904' for key 'PRIMARY'")
# (1062, "Duplicate entry '2111953' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112001' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112100' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112209' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112233' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112274' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112308' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112407' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112456' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112506' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112605' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112704' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112803' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112852' for key 'PRIMARY'")
# (1062, "Duplicate entry '2112902' for key 'PRIMARY'")
# (1062, "Duplicate entry '2113009' for key 'PRIMARY'")
# (1062, "Duplicate entry '2114007' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200053' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200103' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200202' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200251' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200277' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200301' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200400' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200459' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200509' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200608' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200707' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200806' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200905' for key 'PRIMARY'")
# (1062, "Duplicate entry '2200954' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201002' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201051' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201101' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201150' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201176' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201200' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201309' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201408' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201507' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201556' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201572' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201606' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201705' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201739' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201770' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201804' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201903' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201919' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201929' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201945' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201960' for key 'PRIMARY'")
# (1062, "Duplicate entry '2201988' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202000' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202026' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202059' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202075' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202083' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202091' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202109' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202117' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202133' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202174' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202208' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202251' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202307' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202406' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202455' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202505' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202539' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202554' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202604' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202653' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202703' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202711' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202729' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202737' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202752' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202778' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202802' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202851' for key 'PRIMARY'")
# (1062, "Duplicate entry '2202901' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203008' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203107' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203206' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203230' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203255' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203271' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203305' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203354' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203404' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203420' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203453' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203503' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203602' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203701' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203750' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203800' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203859' for key 'PRIMARY'")
# (1062, "Duplicate entry '2203909' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204006' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204105' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204154' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204204' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204303' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204352' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204402' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204501' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204550' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204600' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204659' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204709' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204808' for key 'PRIMARY'")
# (1062, "Duplicate entry '2204907' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205003' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205102' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205151' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205201' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205250' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205276' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205300' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205359' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205409' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205458' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205508' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205516' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205524' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205532' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205540' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205557' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205565' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205573' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205581' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205599' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205607' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205706' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205805' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205854' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205904' for key 'PRIMARY'")
# (1062, "Duplicate entry '2205953' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206001' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206050' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206100' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206209' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206308' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206357' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206407' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206506' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206605' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206654' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206670' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206696' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206704' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206720' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206753' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206803' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206902' for key 'PRIMARY'")
# (1062, "Duplicate entry '2206951' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207009' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207108' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207207' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207306' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207355' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207405' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207504' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207553' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207603' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207702' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207751' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207777' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207793' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207801' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207850' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207900' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207934' for key 'PRIMARY'")
# (1062, "Duplicate entry '2207959' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208007' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208106' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208205' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208304' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208403' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208502' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208551' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208601' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208650' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208700' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208809' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208858' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208874' for key 'PRIMARY'")
# (1062, "Duplicate entry '2208908' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209005' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209104' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209153' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209203' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209302' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209351' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209377' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209401' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209450' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209500' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209559' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209609' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209658' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209708' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209757' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209807' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209856' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209872' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209906' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209955' for key 'PRIMARY'")
# (1062, "Duplicate entry '2209971' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210003' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210052' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210102' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210201' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210300' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210359' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210375' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210383' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210391' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210409' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210508' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210607' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210623' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210631' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210656' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210706' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210805' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210904' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210938' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210953' for key 'PRIMARY'")
# (1062, "Duplicate entry '2210979' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211001' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211100' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211209' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211308' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211357' for key 'PRIMARY'")
# (1062, "Duplicate entry '2211407' for key 'PRIMARY'")
# ...
# (1062, "Duplicate entry '4104428' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104451' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104501' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104600' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104659' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104709' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104808' for key 'PRIMARY'")
# (1062, "Duplicate entry '4104907' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105003' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105102' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105201' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105300' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105409' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105508' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105607' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105706' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105805' for key 'PRIMARY'")
# (1062, "Duplicate entry '4105904' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106001' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106100' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106209' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106308' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106407' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106456' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106506' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106555' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106571' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106605' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106704' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106803' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106852' for key 'PRIMARY'")
# (1062, "Duplicate entry '4106902' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107009' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107108' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107124' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107157' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107207' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107256' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107306' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107405' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107504' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107520' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107538' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107546' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107553' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107603' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107652' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107702' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107736' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107751' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107801' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107850' for key 'PRIMARY'")
# (1062, "Duplicate entry '4107900' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108007' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108106' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108205' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108304' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108320' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108403' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108452' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108502' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108551' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108601' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108650' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108700' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108809' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108908' for key 'PRIMARY'")
# (1062, "Duplicate entry '4108957' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109005' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109104' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109203' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109302' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109401' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109500' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109609' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109658' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109708' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109757' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109807' for key 'PRIMARY'")
# (1062, "Duplicate entry '4109906' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110003' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110052' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110078' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110102' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110201' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110300' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110409' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110508' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110607' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110656' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110706' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110805' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110904' for key 'PRIMARY'")
# (1062, "Duplicate entry '4110953' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111001' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111100' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111209' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111258' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111308' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111407' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111506' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111555' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111605' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111704' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111803' for key 'PRIMARY'")
# (1062, "Duplicate entry '4111902' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112009' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112108' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112207' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112306' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112405' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112504' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112603' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112702' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112751' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112801' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112900' for key 'PRIMARY'")
# (1062, "Duplicate entry '4112959' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113007' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113106' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113205' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113254' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113304' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113403' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113429' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113452' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113502' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113601' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113700' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113734' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113759' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113809' for key 'PRIMARY'")
# (1062, "Duplicate entry '4113908' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114005' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114104' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114203' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114302' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114351' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114401' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114500' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114609' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114708' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114807' for key 'PRIMARY'")
# (1062, "Duplicate entry '4114906' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115002' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115101' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115200' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115309' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115358' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115408' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115457' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115507' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115606' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115705' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115739' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115754' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115804' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115853' for key 'PRIMARY'")
# (1062, "Duplicate entry '4115903' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116000' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116059' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116109' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116208' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116307' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116406' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116505' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116604' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116703' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116802' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116901' for key 'PRIMARY'")
# (1062, "Duplicate entry '4116950' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117008' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117057' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117107' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117206' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117214' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117222' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117255' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117271' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117297' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117305' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117404' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117453' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117503' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117602' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117701' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117800' for key 'PRIMARY'")
# (1062, "Duplicate entry '4117909' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118006' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118105' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118204' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118303' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118402' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118451' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118501' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118600' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118709' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118808' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118857' for key 'PRIMARY'")
# (1062, "Duplicate entry '4118907' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119004' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119103' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119152' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119202' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119251' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119301' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119400' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119509' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119608' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119657' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119707' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119806' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119905' for key 'PRIMARY'")
# (1062, "Duplicate entry '4119954' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120002' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120101' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120150' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120200' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120309' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120333' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120358' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120408' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120507' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120606' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120655' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120705' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120804' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120853' for key 'PRIMARY'")
# (1062, "Duplicate entry '4120903' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121000' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121109' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121208' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121257' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121307' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121356' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121406' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121505' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121604' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121703' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121752' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121802' for key 'PRIMARY'")
# (1062, "Duplicate entry '4121901' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122008' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122107' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122156' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122172' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122206' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122305' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122404' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122503' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122602' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122651' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122701' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122800' for key 'PRIMARY'")
# (1062, "Duplicate entry '4122909' for key 'PRIMARY'")
# (1062, "Duplicate entry '4123006' for key 'PRIMARY'")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c7a5a3bfe326> in <module>
#       1 salvaCidadeJson()
#       2 cidades = lerCidadesJson()
# ----> 3 insereCidadesBanco(cidades)
#       4
#       5 #Contagem de tempo
#
# <ipython-input-6-8dd367fc572a> in insereCidadesBanco(cidades)
#       7     #         print(sql)
#       8             cursor = con.cursor()
# ----> 9             cursor.execute(sql)
#      10             con.commit()
#      11         except pymysql.IntegrityError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     514             else:
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 516         self._execute_command(COMMAND.COM_QUERY, sql)
#     517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     769         prelude = struct.pack('<iB', packet_size, command)
#     770         packet = prelude + sql[:packet_size-1]
# --> 771         self._write_bytes(packet)
#     772         if DEBUG: dump_packet(packet)
#     773         self._next_seq_id = 1
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _write_bytes(self, data)
#     711         self._sock.settimeout(self._write_timeout)
#     712         try:
# --> 713             self._sock.sendall(data)
#     714         except IOError as e:
#     715             self._force_close()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Pesquisas
# * Recuperando pesquisas salvando num json
# * Lendo json salvando pesquisas num vetor
# * Adicionando pesquisas no banco

# %%
salvaPesquisaJson()
pesquisas = lerPesquisasJson()
inserePesquisasBanco(pesquisas)

#Contagem de tempo
pesquisaTime = time.time()

# %% [markdown]
# ## Indicadores
# * Recuperando indicadoress salvando num json
# * Lendo json salvando indicadores num vetor
# * Adicionando indicadores no banco

# %%
salvaIndicadoresJson(pesquisas)
indicadores = lerIndicadoresJson(pesquisas)
insereIndicadoresBanco(indicadores)

#Contagem de tempo
indicadoresTime = time.time()
# Out:
# A pesquisa 1 nao possui indicadores
# A pesquisa 24 nao possui indicadores
# A pesquisa 45 nao possui indicadores
# A pesquisa 10072 nao possui indicadores
# A pesquisa 10079 nao possui indicadores
# A pesquisa 10085 nao possui indicadores

# %% [markdown]
# ## Histórico
# * Recuperando indicadoress a serem pesquisados do banco (Os indicadores a serem pesquisados estão em src/pesquisa/indicadores/indicarores.txt)
# * Recuperando historico e salvando num json em src/historico (o nome de cada json sera o id de cada cidade)
# * Lendo json dos historicos e salvando em um vetor
# * Adicionando o historico no banco

# %%
indicadoresASeremPesquisados = retornaIndicadoresASeremPesquisados()
salvaHistoricoParaCidadesJson(cidades,indicadoresASeremPesquisados)
historico = lerHistoricoJson(cidades)
insereHistoricoBanco(historico)

#Contagem de tempo
historicoTime = time.time()

# %%
#Contagem de tempo
fimTime = time.time()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-164b2a27718a> in <module>
#       1 #Contagem de tempo
# ----> 2 fimTime = time.time()
#
# NameError: name 'time' is not defined

# %%
print("Tempo gasto total"+str(fimTime - inicioTime))
